# %%
import csv
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# DeepMoD stuff
from deepymod import DeepMoD
from deepymod.model.func_approx import NN, Siren
from deepymod.model.library import Library1D
from deepymod.model.constraint import LeastSquares
from deepymod.model.sparse_estimators import Clustering, Threshold
from deepymod.training import train
from deepymod.training.sparsity_scheduler import TrainTestPeriodic
from scipy.io import loadmat
# Setting cuda
#if torch.cuda.is_available():

#    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    
# Settings for reproducibility
np.random.seed(42)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
data = loadmat('cable_exp_20bis.mat')
usol = np.real(data['Expression1'])
usol= usol.reshape((20,200,3))
x_v= usol[:,:,0]
t_v = usol[:,:,1]
u_v = usol[:,:,2]

# %%
new_uv= np.take(u_v,np.arange(0,u_v.shape[0],1),axis=0)

# %%
new_uv.shape
# Out:
# (20, 200)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(u_v,aspect=10)

# %%
noise_level = 0.05

# %%
u_v_noise =   u_v + noise_level * np.std(u_v) * np.random.randn(u_v.shape[0],u_v.shape[1])

# %%
u_v_noise.shape
# Out:
# (20, 200)

# %%
plt.plot(u_v_noise[4,:])
plt.plot(u_v[4,:])

# %%
plt.figure(figsize=(6, 6))
plt.imshow(u_v_noise,aspect=10)

# %%
output_data = np.take(u_v_noise,np.arange(0,u_v_noise.shape[0],1),axis=0)
output_data.shape
# Out:
# (20, 200)

# %%
x = np.linspace(0, 1, output_data.shape[0])
t = np.linspace(0, 1, output_data.shape[1])

# %%
x_grid, t_grid = np.meshgrid(x, t, indexing='ij')

# %%
X = np.transpose((t_grid.flatten(), x_grid.flatten()))
y = np.real(output_data).reshape((output_data.size, 1))
y = y/np.max(y)

# %%
number_of_samples = 2000

idx = np.random.permutation(y.shape[0])
X_train = torch.tensor(X[idx, :][:number_of_samples], dtype=torch.float32, requires_grad=True)
y_train = torch.tensor(y[idx, :][:number_of_samples], dtype=torch.float32)

# %%
network = NN(2, [30, 30, 30, 30], 1)

# %% [markdown]
# Configuration of the library function: We select athe library with a 2D spatial input. Note that that the max differential order has been pre-determined here out of convinience. So, for poly_order 1 the library contains the following 12 terms:
# * [$1, u_x, u_{xx}, u_{xxx}, u, u u_{x}, u u_{xx}, u u_{xxx}, u^2, u^2 u_{x}, u^2 u_{xx}, u^2 u_{xxx}$]

# %%
library = Library1D(poly_order=1, diff_order=2)

# %% [markdown]
# Configuration of the sparsity estimator and sparsity scheduler used. In this case we use the most basic threshold-based Lasso estimator and a scheduler that asseses the validation loss after a given patience. If that value is smaller than 1e-5, the algorithm is converged.

# %%
estimator = Threshold(0.1) 
sparsity_scheduler = TrainTestPeriodic(periodicity=50, patience=200, delta=1e-5)

# %% [markdown]
# Configuration of the sparsity estimator

# %%
constraint = LeastSquares() 
# Configuration of the sparsity scheduler

# %% [markdown]
# Now we instantiate the model and select the optimizer

# %%
model = DeepMoD(network, library, estimator, constraint)

# %%
# Defining optimizer
optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.99), amsgrad=True, lr=2e-3)

# %% [markdown]
# ## Run DeepMoD

# %% [markdown]
# We can now run DeepMoD using all the options we have set and the training data:
# * The directory where the tensorboard file is written (log_dir)
# * The ratio of train/test set used (split)
# * The maximum number of iterations performed (max_iterations)
# * The absolute change in L1 norm considered converged (delta)
# * The amount of epochs over which the absolute change in L1 norm is calculated (patience)

# %%
train(model, X_train, y_train, optimizer,sparsity_scheduler, log_dir='runs/theory/', split=0.8, max_iterations=200000, delta=1e-7, patience=200)
# Out:
#  64625  MSE: 2.17e-04  Reg: 3.65e-06  L1: 6.97e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-76a8e7491755> in <module>
# ----> 1 train(model, X_train, y_train, optimizer,sparsity_scheduler, log_dir='runs/theory/', split=0.8, max_iterations=200000, delta=1e-7, patience=200)
#
# ~/Documents/working/DeePyMoD/src/deepymod/training/training.py in train(model, data, target, optimizer, sparsity_scheduler, split, exp_ID, log_dir, max_iterations, write_iterations, **convergence_kwargs)
#      43     for iteration in torch.arange(0, max_iterations):
#      44         # ================== Training Model ============================
# ---> 45         prediction, time_derivs, thetas = model(data_train)
#      46
#      47         MSE = torch.mean((prediction - target_train)**2, dim=0)  # loss per output
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Documents/working/DeePyMoD/src/deepymod/model/deepmod.py in forward(self, input)
#     151         """
#     152         prediction, coordinates = self.func_approx(input)
# --> 153         time_derivs, thetas = self.library((prediction, coordinates))
#     154         self.constraint((time_derivs, thetas))
#     155         return prediction, time_derivs, thetas
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Documents/working/DeePyMoD/src/deepymod/model/deepmod.py in forward(self, input)
#     114             Tuple[TensorList, TensorList]: [description]
#     115         """
# --> 116         time_derivs, thetas = self.library(input)
#     117         self.norms = [(torch.norm(time_deriv) / torch.norm(theta, dim=0, keepdim=True)).detach().squeeze() for time_deriv, theta in zip(time_derivs, thetas)]
#     118         return time_derivs, thetas
#
# ~/Documents/working/DeePyMoD/src/deepymod/model/library.py in library(self, input)
#      82         for output in np.arange(prediction.shape[1]):
#      83             time_deriv, du = library_deriv(data, prediction[:, output:output+1], self.diff_order)
# ---> 84             u = library_poly(prediction[:, output:output+1], self.poly_order)
#      85
#      86             poly_list.append(u)
#
# ~/Documents/working/DeePyMoD/src/deepymod/model/library.py in library_poly(prediction, max_order)
#      21     """
#      22     u = torch.ones_like(prediction)
# ---> 23     for order in np.arange(1, max_order+1):
#      24         u = torch.cat((u, u[:, order-1:order] * prediction), dim=1)
#      25
#
# KeyboardInterrupt:

# %%
print(model.estimator_coeffs())
# Out:
# [array([[ 0.       ],
#        [ 0.       ],
#        [ 3.6277647],
#        [-3.304906 ],
#        [ 0.       ],
#        [ 0.       ]], dtype=float32)]

# %%
sol = model(torch.tensor(X, dtype=torch.float32))[0].reshape(output_data.shape).detach().numpy()

# %%
ux = model(torch.tensor(X, dtype=torch.float32))[2][0][:,1].reshape(output_data.shape).detach().numpy()
uxx = model(torch.tensor(X, dtype=torch.float32))[2][0][:,2].reshape(output_data.shape).detach().numpy()

# %%
import pysindy as ps

# %%
fd_spline = ps.SINDyDerivative(kind='spline', s=1e-2)
fd_spectral = ps.SINDyDerivative(kind='spectral')
fd_sg = ps.SINDyDerivative(kind='savitzky_golay', left=0.5, right=0.5, order=3)

# %%
ground_truth = u_v

# %%
u_v.shape
# Out:
# (20, 200)

# %%
u_v_noise.shape
# Out:
# (20, 200)

# %%
sol.shape
# Out:
# (20, 200)

# %%
t0 = 100

# %%
plt.plot(u_v_noise[:,t0],'go--')
plt.plot(u_v[:,t0],'ro')
plt.plot(sol[:,t0]*np.max(output_data),'r')

# %%
t0=50

# %%
plt.plot(fd_sg(u_v_noise[:,t0],x),'go--')
plt.plot(fd_sg(u_v[:,t0],x),'ro')
plt.plot(ux[:,t0]*np.max(output_data),'r')

# %%
plt.plot(fd_sg(fd_sg(u_v_noise[:,t0],x),x),'go--')
plt.plot(fd_sg(fd_sg(u_v[:,t0],x),x),'ro')
plt.plot(uxx[:,t0]*np.max(output_data),'r')

# %% [markdown]
# ## SVD

# %%
u_v_noise.shape
# Out:
# (20, 200)

# %%
steps =
# Out:
#   File "<ipython-input-95-9444081fa5a7>", line 1
#     steps =
#             ^
# SyntaxError: invalid syntax

# %%
dim_w = 2
denoised_sol = []
for i in np.arange(steps):
    uwn,sigmawn,vwn= np.linalg.svd(u_v_noise[:,i])
    vwn = vwn.T
    denoised_sol.append(uwn[:,0:dim_w].dot(np.diag(sigmawn[0:dim_w]).dot(vwn[:,0:dim_w].T)))
denoised_sol = np.array(denoised_sol).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-9c79fb199971> in <module>
#       1 dim_w = 2
#       2 denoised_sol = []
# ----> 3 for i in np.arange(steps):
#       4     uwn,sigmawn,vwn= np.linalg.svd(u_v_noise[:,i])
#       5     vwn = vwn.T
#
# NameError: name 'steps' is not defined
