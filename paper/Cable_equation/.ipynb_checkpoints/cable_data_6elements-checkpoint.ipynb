# %%
import csv
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# DeepMoD stuff
from deepymod import DeepMoD
from deepymod.model.func_approx import NN, Siren
from deepymod.model.library import Library1D
from deepymod.model.constraint import LeastSquares
from deepymod.model.sparse_estimators import Clustering, Threshold
from deepymod.training import train
from deepymod.training.sparsity_scheduler import TrainTestPeriodic
# Setting cuda
#if torch.cuda.is_available():
#    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    
# Settings for reproducibility
np.random.seed(42)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
V_2_1 = np.loadtxt('data/data_13_10/V1_V2/data_V1.csv', delimiter=',', skiprows=3)
V_2_2 = np.loadtxt('data/data_13_10/V1_V3/data_V1.csv', delimiter=',', skiprows=3)
V_2_3 = np.loadtxt('data/data_13_10/V1_V4/data_V1.csv', delimiter=',', skiprows=3)
V_2_4 = np.loadtxt('data/data_13_10/V1_V5/data_V1.csv', delimiter=',', skiprows=3)
V_2_5 = np.loadtxt('data/data_13_10/V1_V6/data_V1.csv', delimiter=',', skiprows=3)
V_2_6 = np.loadtxt('data/data_13_10/V1_V7/data_V1.csv', delimiter=',', skiprows=3)
V_2_7 = np.loadtxt('data/data_13_10/V1_V8/data_V1.csv', delimiter=',', skiprows=3)
V_2_8 = np.loadtxt('data/data_13_10/V1_V9/data_V1.csv', delimiter=',', skiprows=3)
V_2_9 = np.loadtxt('data/data_13_10/V1_V10/data_V1.csv', delimiter=',', skiprows=3)
V_2_10 = np.loadtxt('data/data_13_10/V1_V11/data_V1.csv', delimiter=',', skiprows=3)
V_2_11 = np.loadtxt('data/data_13_10/V1_V12/data_V1.csv', delimiter=',', skiprows=3)
V_2_12 = np.loadtxt('data/data_13_10/V1_V13/data_V1.csv', delimiter=',', skiprows=3)
V_2_13 = np.loadtxt('data/data_13_10/V1_V14/data_V1.csv', delimiter=',', skiprows=3)
V_2_14 = np.loadtxt('data/data_13_10/V1_V15/data_V1.csv', delimiter=',', skiprows=3)

# %%
data = np.concatenate((V_2_1[:, 1:], V_2_2[:, 1:], V_2_3[:, 1:], V_2_4[:, 1:], V_2_5[:, 1:], V_2_6[:, 1:], V_2_7[:, 1:], V_2_8[:, 1:], V_2_9[:, 1:], V_2_10[:, 1:], V_2_11[:, 1:], V_2_12[:, 1:], V_2_13[:, 1:], V_2_14[:, 1:]), axis=1)

# %%
time = V_2_1[:, 0]

# %%
V2_2 = np.loadtxt('data/data_13_10/V1_V2/data_V2.csv', delimiter=',', skiprows=3)
V2_3 = np.loadtxt('data/data_13_10/V1_V3/data_V3.csv', delimiter=',', skiprows=3)
V2_4 = np.loadtxt('data/data_13_10/V1_V4/data_V4.csv', delimiter=',', skiprows=3)
V2_5 = np.loadtxt('data/data_13_10/V1_V5/data_V5.csv', delimiter=',', skiprows=3)
V2_6 = np.loadtxt('data/data_13_10/V1_V6/data_V6.csv', delimiter=',', skiprows=3)
V2_7 = np.loadtxt('data/data_13_10/V1_V7/data_V7.csv', delimiter=',', skiprows=3)
V2_8 = np.loadtxt('data/data_13_10/V1_V8/data_V8.csv', delimiter=',', skiprows=3)
V2_9 = np.loadtxt('data/data_13_10/V1_V9/data_V9.csv', delimiter=',', skiprows=3)
V2_10 = np.loadtxt('data/data_13_10/V1_V10/data_V10.csv', delimiter=',', skiprows=3)
V2_11 = np.loadtxt('data/data_13_10/V1_V11/data_V11.csv', delimiter=',', skiprows=3)
V2_12 = np.loadtxt('data/data_13_10/V1_V12/data_V12.csv', delimiter=',', skiprows=3)
V2_13 = np.loadtxt('data/data_13_10/V1_V13/data_V13.csv', delimiter=',', skiprows=3)
V2_14 = np.loadtxt('data/data_13_10/V1_V14/data_V14.csv', delimiter=',', skiprows=3)

# %%
delta_V = np.concatenate((V2_2[:, 1:], V2_3[:, 1:], V2_4[:, 1:], V2_5[:, 1:], V2_6[:, 1:], V2_7[:, 1:], V2_8[:, 1:], V2_9[:, 1:], V2_10[:, 1:], V2_11[:, 1:], V2_12[:, 1:], V2_13[:, 1:], V2_14[:, 1:]), axis=1)
#delta_V_1 = np.concatenate((V10_2[:, 1:], V10_3[:, 1:], V10_4[:, 1:], V10_5[:, 1:], V10_6[:, 1:], V10_7[:, 1:], V10_8[:, 1:], V10_9[:, 1:], V10_10[:, 1:]), axis=1)

# %%
upper_lim = 3000 
lower_lim = 540

# %%
plt.figure(figsize=(6, 6))
plt.imshow(delta_V[lower_lim:upper_lim,:],aspect=0.002)

# %%
plt.figure(figsize=(6, 4))
plt.plot(V2_2[540:3000, 1])
plt.plot(V2_3[540:3000, 1])
plt.plot(V2_4[540:3000, 1])
plt.plot(V2_5[540:3000, 1])
plt.plot(V2_6[540:3000, 1])
plt.plot(V2_7[540:3000, 1])
plt.plot(V2_8[540:3000, 1])
plt.plot(V2_9[540:3000, 1])
plt.plot(V2_10[540:3000, 1])
plt.plot(V2_11[540:3000, 1])
plt.plot(V2_12[540:3000, 1])
plt.plot(V2_13[540:3000, 1])
plt.plot(V2_14[540:3000, 1])
#plt.plot(time, V2_4[:, 1])

# %%
output_data = delta_V[lower_lim:upper_lim,:].T
output_data.shape
# Out:
# (13, 2460)

# %%
x = np.linspace(0, 1, output_data.shape[0])
t = np.linspace(0, 1, output_data.shape[1])

# %%
x_grid, t_grid = np.meshgrid(x, t, indexing='ij')

# %%
X = np.transpose((t_grid.flatten(), x_grid.flatten()))
y = np.real(output_data).reshape((output_data.size, 1))
y = y/np.max(y)

# %%
number_of_samples = 5000

idx = np.random.permutation(y.shape[0])
X_train = torch.tensor(X[idx, :][:number_of_samples], dtype=torch.float32, requires_grad=True)
y_train = torch.tensor(y[idx, :][:number_of_samples], dtype=torch.float32)

# %%
network = NN(2, [30, 30, 30, 30], 1)

# %% [markdown]
# Configuration of the library function: We select athe library with a 2D spatial input. Note that that the max differential order has been pre-determined here out of convinience. So, for poly_order 1 the library contains the following 12 terms:
# * [$1, u_x, u_{xx}, u_{xxx}, u, u u_{x}, u u_{xx}, u u_{xxx}, u^2, u^2 u_{x}, u^2 u_{xx}, u^2 u_{xxx}$]

# %%
library = Library1D(poly_order=1, diff_order=2)

# %% [markdown]
# Configuration of the sparsity estimator and sparsity scheduler used. In this case we use the most basic threshold-based Lasso estimator and a scheduler that asseses the validation loss after a given patience. If that value is smaller than 1e-5, the algorithm is converged.

# %%
estimator = Threshold(0.05) 
sparsity_scheduler = TrainTestPeriodic(periodicity=50, patience=10, delta=1e-5)

# %% [markdown]
# Configuration of the sparsity estimator

# %%
constraint = LeastSquares() 
# Configuration of the sparsity scheduler

# %% [markdown]
# Now we instantiate the model and select the optimizer

# %%
model = DeepMoD(network, library, estimator, constraint)

# %%
# Defining optimizer
optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.99), amsgrad=True, lr=2e-3)

# %% [markdown]
# ## Run DeepMoD

# %% [markdown]
# We can now run DeepMoD using all the options we have set and the training data:
# * The directory where the tensorboard file is written (log_dir)
# * The ratio of train/test set used (split)
# * The maximum number of iterations performed (max_iterations)
# * The absolute change in L1 norm considered converged (delta)
# * The amount of epochs over which the absolute change in L1 norm is calculated (patience)

# %%
train(model, X_train, y_train, optimizer,sparsity_scheduler, log_dir='runs/test_2/', split=0.8, max_iterations=100000, delta=1e-7, patience=200)
# Out:
#  26550  MSE: 2.45e-04  Reg: 2.42e-05  L1: 1.93e+01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-37bdfd83bf63> in <module>
# ----> 1 train(model, X_train, y_train, optimizer,sparsity_scheduler, log_dir='runs/test_2/', split=0.8, max_iterations=100000, delta=1e-7, patience=200)
#
# ~/Documents/working/DeePyMoD/src/deepymod/training/training.py in train(model, data, target, optimizer, sparsity_scheduler, split, exp_ID, log_dir, max_iterations, write_iterations, **convergence_kwargs)
#      43     for iteration in torch.arange(0, max_iterations):
#      44         # ================== Training Model ============================
# ---> 45         prediction, time_derivs, thetas = model(data_train)
#      46
#      47         MSE = torch.mean((prediction - target_train)**2, dim=0)  # loss per output
#
# ...

# %%
print(model.estimator_coeffs())
# Out:
# [array([[ 0.       ],
#        [-3.1275425],
#        [ 1.462164 ],
#        [-3.661736 ],
#        [-0.681121 ],
#        [-3.9109163]], dtype=float32)]

# %%
sol = model(torch.tensor(X, dtype=torch.float32))[0].reshape(output_data.shape).detach().numpy()
